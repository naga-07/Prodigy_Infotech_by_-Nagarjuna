# %% [markdown]
# # **Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.** Nagarjuna

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the Titanic dataset
data = pd.read_csv('train.csv')

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# The Titanic dataset is a well-known dataset frequently used for teaching and practice in data analysis, machine learning, and data science. It contains information about passengers who were on board the RMS Titanic during its ill-fated maiden voyage, which ended tragically with the ship sinking after hitting an iceberg in April 1912.
#
# The dataset typically includes various attributes (columns) for each passenger, providing insights into their characteristics and circumstances. Some of the common attributes in the dataset include:
#
# PassengerId: A unique identifier for each passenger.
# Survived: Indicates whether a passenger survived (1) or did not survive (0).
# Pclass: The passenger's class of travel (1st, 2nd, or 3rd class).
# Name: The passenger's name.
# Sex: The gender of the passenger.
# Age: The age of the passenger.
# SibSp: The number of siblings or spouses the passenger had aboard the Titanic.
# Parch: The number of parents or children the passenger had aboard the Titanic.
# Ticket: The ticket number.
# Fare: The fare paid for the ticket.
# Cabin: The cabin number where the passenger stayed.
# Embarked: The port where the passenger embarked (C = Cherbourg, Q = Queenstown, S = Southampton).
# An overview of the dataset involves exploring the dataset's structure, checking for missing values, understanding the data distribution, and identifying patterns. Common tasks during overview and exploratory data analysis include:
#
# Loading the Data: Load the dataset using a library like Pandas.
# Inspecting the Data: Display a sample of the data to understand its structure.
# Handling Missing Values: Identify and handle missing values if present.
# Summarizing Statistics: Compute basic statistics (mean, median, etc.) for numeric columns.
# Visualization: Create plots to visualize distributions, relationships, and trends.
# Feature Exploration: Analyze specific features or variables to understand their impact on survival.
# The Titanic dataset is often used to answer questions like:
#
# What factors influenced survival rates? (e.g., gender, age, class)
# Were passengers in higher classes more likely to survive?
# How did age and gender affect survival?
# Did having family members on board affect the chances of survival?
# Exploring and analyzing the Titanic dataset provides valuable practice for data cleaning, visualization, and basic statistical analysis, which are essential skills in the field of data science.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
#Data Cleaning
data[data == '?'] = np.nan
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Categorical Values
categorical_cols = ['Name','Sex','Ticket','Cabin','Embarked']
for col in categorical_cols:
  data[col] = data[col].astype('category')

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    category
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    category
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    category
#  11  Embarked     889 non-null    category
# dtypes: category(5), float64(2), int64(5)
# memory usage: 128.9 KB

# %%
numeric_cols = ['Age','PassengerId','Survived','Pclass','Age','SibSp','Parch','fare']

# %%
sns.set_palette("pastel")
plt.figure(figsize=(8, 5))
plt.title('No Of people Survived', fontsize=16, fontweight='bold')
eda_percentage = data['Survived'].value_counts(normalize=True).rename_axis('Name').reset_index(name='Percentage')

ax = sns.barplot(x='Name', y='Percentage', data=eda_percentage.head(10))
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height:.0%}', (x + width/2, y + height*1.02), ha='center', fontweight='bold')

# %%
plt.figure(figsize=(12, 5))
plt.title("Correlation between different features of the dataset", fontsize=18, fontweight='bold')
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")  # Changing the color palette to "coolwarm"
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Explore the distribution of 'Survived'
sns.countplot(data['Survived'])
plt.title('Survival Distribution')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
# Explore the relationship between 'Survived' and 'PassengerId'
plt.figure(figsize=(8, 6))
sns.boxplot(x='Survived', y='PassengerId', data=data)
plt.title('Survival vs PassengerId')
plt.show()

# %%
# Calculate the survival rate
survival_rate = data['Survived'].value_counts(normalize=True) * 100
print('Survival Rate:')
print(survival_rate)
# Out:
# Survival Rate:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
# Calculate the average PassengerId for survivors and non-survivors
avg_passenger_id_survived = data[data['Survived'] == 1]['PassengerId'].mean()
avg_passenger_id_not_survived = data[data['Survived'] == 0]['PassengerId'].mean()
print('Average PassengerId for Survivors:', avg_passenger_id_survived)
print('Average PassengerId for Non-Survivors:', avg_passenger_id_not_survived)
# Out:
# Average PassengerId for Survivors: 444.36842105263156
# Average PassengerId for Non-Survivors: 447.0163934426229
